# %%
import pandas as pd
import seaborn as sns
import warnings
warnings.simplefilter("ignore")

from benchmarks.bench_physipy import BenchPhysipy
from benchmarks.bench_pint import BenchPint
from benchmarks.bench_astropy import BenchAstropy
from benchmarks.base import BenchNumpy
import pandas as pd

bnp = BenchNumpy()
bench_physipy = BenchPhysipy()
bench_pint = BenchPint()
bench_astropy = BenchAstropy()

# %%
rall = bnp.bench_all()

# %%
make_results = bench_physipy.set_qarrays() + bench_physipy.set_qscalars() + bench_pint.set_qarrays() + bench_pint.set_qscalars() 
#+ 
make_results = make_results + bench_astropy.set_qarrays() + bench_astropy.set_qscalars()

# %%
df = pd.DataFrame.from_records(make_results)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45 entries, 0 to 44
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   module  45 non-null     object
#  1   unit    45 non-null     object
#  2   from    45 non-null     object
#  3   passed  45 non-null     bool
#  4   result  45 non-null     object
#  5   time    45 non-null     float64
# dtypes: bool(1), float64(1), object(4)
# memory usage: 1.9+ KB

# %%
g = sns.catplot(x="module", y="time",
                hue="from", col="unit",
                data=df, kind="bar",
                height=4, aspect=.7);

# %%
df
# Out:
#            module unit                            from  passed  \
# 0         physipy    m                           (10,)    True
# 1         physipy    m                         (1000,)    True
# 2         physipy    m                      (100, 100)    True
# 3         physipy    m  (2, 2, 2, 2, 2, 2, 2, 2, 2, 2)    True
# 4         physipy    s                           (10,)    True
# 5         physipy    s                         (1000,)    True
# 6         physipy    s                      (100, 100)    True
# 7         physipy    s  (2, 2, 2, 2, 2, 2, 2, 2, 2, 2)    True
# 8         physipy    J                           (10,)    True
# 9         physipy    J                         (1000,)    True
# 10        physipy    J                      (100, 100)    True
# 11        physipy    J  (2, 2, 2, 2, 2, 2, 2, 2, 2, 2)    True
# 12        physipy    m                            1.23    True
# 13        physipy    s                            1.23    True
# ...

# %%
sns.catplot(x="module", y="time", hue="from", kind="bar", data=df, col="unit")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/5k/bf4syt7x1zjbhc6b28srzzym0000gn/T/ipykernel_20615/2990382870.py in <module>
# ----> 1 sns.catplot(x="module", y="time", hue="from", kind="bar", data=df, col="unit")
#
# NameError: name 'sns' is not defined

# %%
python_res_dict = bnp.bench_unary_funcs(bnp.python_unary_ops)

# %%
numpy_res_dict = bnp.bench_unary_funcs(bnp.numpy_unary_ufuncs)
# Out:
# /Users/mocquin/Documents/CLE/Optique/Python/JUPYTER/MYLIB10/MODULES/quantities-comparison/benchmarks/base.py:237: RuntimeWarning: invalid value encountered in log
#   res = f(sca)
# /Users/mocquin/Documents/CLE/Optique/Python/JUPYTER/MYLIB10/MODULES/quantities-comparison/benchmarks/base.py:239: RuntimeWarning: invalid value encountered in log
#   time = self.timeit(lambda :f(sca))
# /Users/mocquin/Documents/CLE/Optique/Python/JUPYTER/MYLIB10/MODULES/quantities-comparison/benchmarks/base.py:237: RuntimeWarning: divide by zero encountered in log
#   res = f(sca)
# /Users/mocquin/Documents/CLE/Optique/Python/JUPYTER/MYLIB10/MODULES/quantities-comparison/benchmarks/base.py:239: RuntimeWarning: divide by zero encountered in log
#   time = self.timeit(lambda :f(sca))
# /Users/mocquin/Documents/CLE/Optique/Python/JUPYTER/MYLIB10/MODULES/quantities-comparison/benchmarks/base.py:237: RuntimeWarning: invalid value encountered in log2
#   res = f(sca)
# ...

# %%
df = pd.DataFrame.from_records(python_res_dict+numpy_res_dict)

# %%
df
# Out:
#     package                     func func_kind naryness  \
# 0    python  <built-in function abs>    python    unary
# 1    python  <built-in function abs>    python    unary
# 2    python  <built-in function abs>    python    unary
# 3    python  <built-in function abs>    python    unary
# 4    python  <built-in function abs>    python    unary
# ..      ...                      ...       ...      ...
# 283  python          <ufunc 'trunc'>    python    unary
# 284  python          <ufunc 'trunc'>    python    unary
# 285  python          <ufunc 'trunc'>    python    unary
# 286  python          <ufunc 'trunc'>    python    unary
# 287  python          <ufunc 'trunc'>    python    unary
#
#                                                   left type_left right  \
# 0                                                 -1.1    scalar  None
# 1                                                 -1.0    scalar  None
# 2                                                    0    scalar  None
# ...
